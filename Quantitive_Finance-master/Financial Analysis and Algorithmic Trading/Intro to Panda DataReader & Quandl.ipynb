# %%
import pandas_datareader.data as web
# Out:
# /Users/dennismacpro/miniconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
import datetime

# %%
start = datetime.datetime(2015,1,1)
end = datetime.datetime(2017,1,1)

# %%
facebook = web.DataReader('FB','yahoo',start,end)
facebook.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-01-02  78.930000  77.699997  78.580002  78.449997  18177500  78.449997
# 2015-01-05  79.250000  76.860001  77.980003  77.190002  26452200  77.190002
# 2015-01-06  77.589996  75.360001  77.230003  76.150002  27399300  76.150002
# 2015-01-07  77.360001  75.820000  76.760002  76.150002  22045300  76.150002
# 2015-01-08  78.230003  76.080002  76.739998  78.180000  23961000  78.180000

# %%
# zKYsMEfvyGrpJ-bk5J2V
# https://docs.quandl.com/docs/python

# %%
import quandl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c982d674eccd> in <module>
# ----> 1 import quandl
#
# ModuleNotFoundError: No module named 'quandl'

# %%
quandl.ApiConfig.api_key = 'zKYsMEfvyGrpJ-bk5J2V'

# %%
r = quandl.get('EOD/HD', start_date='2017-12-28', end_date='2017-12-28')
r.head()
# Out:
#               Open    High     Low   Close     Volume  Dividend  Split  \
# Date
# 2017-12-28  190.91  190.98  189.64  189.78  3175631.0       0.0    1.0
#
#               Adj_Open   Adj_High     Adj_Low   Adj_Close  Adj_Volume
# Date
# 2017-12-28  180.531515  180.59771  179.330556  179.462946   3175631.0

# %%
quandl.get('EOD/HD', column_index='1')
# Out:
#               Open
# Date
# 2013-09-03   74.83
# 2013-09-04   73.98
# 2013-09-05   74.07
# 2013-09-06   73.55
# 2013-09-09   72.98
# ...            ...
# 2017-12-21  187.70
# 2017-12-22  188.20
# 2017-12-26  188.53
# 2017-12-27  190.60
# 2017-12-28  190.91
#
# [1090 rows x 1 columns]

# %%
quandl.get('EOD/HD', start_date='2017-12-26', end_date='2017-12-28')
# Out:
#               Open    High     Low   Close     Volume  Dividend  Split  \
# Date
# 2017-12-26  188.53  190.42  188.34  190.36  2969182.0       0.0    1.0
# 2017-12-27  190.60  191.49  190.01  190.19  5912613.0       0.0    1.0
# 2017-12-28  190.91  190.98  189.64  189.78  3175631.0       0.0    1.0
#
#               Adj_Open    Adj_High     Adj_Low   Adj_Close  Adj_Volume
# Date
# 2017-12-26  178.280900  180.068153  178.101229  180.011415   2969182.0
# 2017-12-27  180.238368  181.079985  179.680442  179.850657   5912613.0
# 2017-12-28  180.531515  180.597710  179.330556  179.462946   3175631.0

# %%
mydata = quandl.get('EIA/PET_RWTC_D')
mydata.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata.plot()

# %%
mydata
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# ...           ...
# 2020-04-07  23.54
# 2020-04-08  24.97
# 2020-04-09  22.90
# 2020-04-13  22.36
# 2020-04-14  20.15
#
# [8660 rows x 1 columns]

# %%
zillow = quandl.get('ZILLOW/C9_ZRIFAH')
zillow.plot()

# %%
wiki = quandl.get("WIKI/AAPL")
wiki.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0
