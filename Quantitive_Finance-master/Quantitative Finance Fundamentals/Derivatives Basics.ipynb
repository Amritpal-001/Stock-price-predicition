# %% [markdown]
# # Derivatives
#
# A derivative is a security with a price that is derived from one or more underlying assets
#
# Value of the derivative is determined by fluctuations in the underlying asset
#
# underlying asset: stocks, currenices, or interest rates
#
# derivatives can be used to ensure balanced exchange rates for good traded internationally
#
# Internal traders needed a system of accounting for differing values of different national currencies
#
# derivatives can be used for insuring against risk in an asset (hedging)
#
# ## Future Contracts
# an agreement between two parties for the sale of an asset at an agreed upon price
#
# why is it good? in oorder to hedge against risk during a given period time.
#
# Example. Tom owns 5000 shares of IBM with a value of $50 per share. Fearing that the value of this shares would decline, Tom arranges a future contract to protect the future value of his stocks.
#
# Bob on the hand specualtes that IBM stocks will rise in value. So they agree in 1 years time Bob will buy Toms 5000 shares at their current value of $50.
#
# <img src="images/future_loss.png" />
#
# <img src="images/future_profit.png" />

# %% [markdown]
# ## Intereset Rate Swaps
#
# The swap of future interest payments Agreement between twoo parties in which onoe stream of future interest payments is exchanged for another
#
# For example: fixed interest rate for a floating interesting rate or vica versa
#
# Why is it good? In order to reduce or increase exposure to fluctuations in interest rates
# (earn income through speculation)
#
# Payer
# Agrees to pay fixed rate interest
#
# Reciever
# Agrees to pay floating rate interest
#
# They agree to make payment to each other according to the rise and fall of the floating interest rate
#
# <img src="images/interest_rate_swap.png" />
#
# <img src="images/interest_rate_swap_decrease.png" />

# %% [markdown]
# ## Options
#
# Similar to futures conotracts
# For future contracts the holder of the contract is obliged to trade the maturity of the cnotract
#
# for options, the option gives the holder the right to trade in the future at a previously agreed price, but not obligation at all
#
# so if the stock falls we not have to buy it after all
#
# How to calculate the price of an option??
# ### WITH THE BLACK-SCHOLES MODEL
#
# ### Call Option
#
# This is the right to buy a particular asset (stock) for an agreed amount at a specific time in the future
#
# For example you can buy a call option on IBM.
# ```
# It gives the right to buy on IBM stock for $30 in 1 months time. Today the price is $25.
#
# Exercise price / strike price: E = $30.
# Expiration date / expiry: T = 1 months time (when we can buy the underlying)
# The actual stock price: it is changing all the time S(t) S(t=0)= $25
#
# max(S-E,0) this is what the call option worth at expiry
# if the price is higher hten the strike price then we will make a profit.
#
# For a call option we speculate that the stock still rise
# ```
#
# <img src="images/call_option_expiry.png" />
#
# ### Put Option
#
# This is the right to sell a particular asset (stock) for an agreed amouont at a specific time in the future
# ```
# For example: you can buy a put option on IBM. It gives the right to sell on IBM stock for $30 in 1 months time. Todays prices is $25.
#
# Excerise price or strike price: E = $30
# Expiratino date or expiry is T = 1 months time (When we can buy the underlying)
# The actual stock price it is changing all the time S(T) = S(T=0)=$25
#
# max(E-S,0) this is the put optiono worth at expiry.
# ```
# For A PUT OPTION we speculate that the stock will fall
#
# <img src="images/put_optioon_expiry.png" />
#
# ### American And European Options
# 1. American Option: May be exercised at any time t<T time before expiry time
# 2. European Option: this type of option can be exervised only at the expiration date
